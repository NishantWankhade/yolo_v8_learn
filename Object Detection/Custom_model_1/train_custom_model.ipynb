# %%
# !pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 591.4/591.4 kB 33.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 206.5/206.5 kB 18.7 MB/s eta 0:00:00
# ...

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/Training custom model
# Out:
# /content/drive/MyDrive/Colab Notebooks/Training custom model

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=data.yaml epochs=3
# Out:
# ...
# 100% 21.5M/21.5M [00:01<00:00, 12.1MB/s]
# Ultralytics YOLOv8.0.109 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=predict model=best.pt source="/content/drive/MyDrive/Colab Notebooks/00053.jpg" save=True
# Out:
# Ultralytics YOLOv8.0.109 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11127132 parameters, 0 gradients
#
# image 1/1 /content/drive/MyDrive/Colab Notebooks/00053.jpg: 384x640 1 prohibitory, 1 mandatory, 58.7ms
# Speed: 2.2ms preprocess, 58.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
