# %%
# !pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 591.4/591.4 kB 11.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 206.5/206.5 kB 27.3 MB/s eta 0:00:00
# ...

# %%
# !yolo task=detect mode=train model=yolov8m.pt data="/content/drive/MyDrive/Colab Notebooks/Custom_model_2/data_custom.yaml" epochs=10
# Out:
# Ultralytics YOLOv8.0.109 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/Custom_model_2
# Out:
# /content/drive/MyDrive/Colab Notebooks/Custom_model_2

# %%
# !yolo detect predict model="/content/drive/MyDrive/Colab Notebooks/Custom_model_2/runs/detect/train5/weights/best.pt" source=images.jpg
# Out:
# Ultralytics YOLOv8.0.109 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25840918 parameters, 0 gradients
#
# image 1/1 /content/drive/MyDrive/Colab Notebooks/Custom_model_2/images.jpg: 416x640 10 class_0s, 5 class_1s, 69.7ms
# Speed: 3.3ms preprocess, 69.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict2
